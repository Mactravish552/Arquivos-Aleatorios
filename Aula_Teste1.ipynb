# %% [markdown]
# <a href="https://colab.research.google.com/github/Mactravish552/Arquivos-Aleatorios/blob/main/Aula_Teste1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Meu nome é Guilherme")
# Out:
# Meu nome é Guilherme

# %% [markdown]
# meu novo código em python

# %%
import pandas as pd

tabela = pd.read_excel("/content/drive/MyDrive/FATEC/API - PlanejaSJC/populacao_subsetores_completo.xlsx")
display(tabela)
# Out:
#      Região Setor Subsetor        Subsetor – Nome  População
# 0    Centro     3    03.01                 Centro       7205
# 1    Centro     3    03.02      Jardim Bela Vista       2405
# 2    Centro     3    03.03             Vila Maria       4607
# 3    Centro     3    03.04      Vila Nova Guarani       1358
# 4    Centro   03A   03A.01                Banhado        665
# ..      ...   ...      ...                    ...        ...
# 168     Sul    16    16.07           Menino Jesus        345
# 169     Sul    16    16.08           Rio Comprido       1775
# 170     Sul    16    16.09  Palmeiras de São José       3452
# 171     Sul    28    28.01              Vila Nair       3073
# 172     Sul    28    28.02         Vila São Bento       2374
#
# [173 rows x 5 columns]

# %%
# !python "/content/Lista 1 (Ex1-11).py"
# Out:
# digite o 1ºnumero:
